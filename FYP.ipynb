# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !mkdir -p /drive/ngrok-ssh
# %cd /drive/ngrok-ssh
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip -O ngrok-stable-linux-amd64.zip
# !unzip -u ngrok-stable-linux-amd64.zip
# !cp /drive/ngrok-ssh/ngrok /ngrok
# !chmod +x /ngrok
# Out:
# /content
# /drive/ngrok-ssh
# --2021-12-23 18:48:44--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 18.205.222.128, 54.237.133.81, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  2.71MB/s    in 12s
#
# 2021-12-23 18:48:57 (1.10 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# !/ngrok authtoken 22Pkv75zTNFxJouVh5dV9803ZLk_7mTsPraNhuoatVfbK1MFr
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !pip install flask_ngrok
# Out:
# Collecting flask_ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask_ngrok) (2.23.0)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask_ngrok) (1.1.4)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_ngrok) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_ngrok) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_ngrok) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_ngrok) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask_ngrok) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask_ngrok) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask_ngrok) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask_ngrok) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask_ngrok) (2021.10.8)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25

# %%
# %cd /content/drive/MyDrive/FYP-WiseTranslator/
# Out:
# /content/drive/MyDrive/FYP-WiseTranslator

# %%
# %ls
# Out:
# app.py             Embedding.py        MultiHeadAttention.py  templates/
# Batching.py        Encoder.py          Normalization.py       Tokenizer.py
# BeamSearch.py      Evaluate.py         Optimizer.py           Trainer.py
# data/              FeedForward.py      PositionalEncoding.py  Translator.py
# DataCleaning.py    FYP.ipynb           Preprocessor.py        weightsETU/
# DataGeneration.py  HyperParameters.py  Reduce.py              weightsUTE/
# Decoder.py         Model.py            static/

# %%
# !python app.py
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# Loading EnglishToUrdu Model...
# loading tokenizers...
# loading presaved fields...
# loading pretrained weights...
# Loading UrduTOEnglish Model...
# loading tokenizers...
# loading presaved fields...
# loading pretrained weights...
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://6b03-35-221-159-249.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [23/Dec/2021 18:53:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Dec/2021 18:53:36] "GET /static/CSS/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Dec/2021 18:53:36] "GET /static/JS/index.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Dec/2021 18:53:38] "GET /favicon.ico HTTP/1.1" 404 -
# ['moving from school to another']
# 127.0.0.1 - - [23/Dec/2021 18:54:04] "POST /onSubmitClick HTTP/1.1" 200 -
# ['ادلے کا بدلہ']
# 127.0.0.1 - - [23/Dec/2021 18:54:29] "POST /onSubmitClick HTTP/1.1" 200 -
# ['بدلہ لینا']
# 127.0.0.1 - - [23/Dec/2021 18:55:13] "POST /onSubmitClick HTTP/1.1" 200 -
# ['fucking']
# 127.0.0.1 - - [23/Dec/2021 18:55:35] "POST /onSubmitClick HTTP/1.1" 200 -
# ['at the same time', '']
# 127.0.0.1 - - [23/Dec/2021 18:55:46] "POST /onSubmitClick HTTP/1.1" 200 -
# ['how are you']
# 127.0.0.1 - - [23/Dec/2021 18:56:00] "POST /onSubmitClick HTTP/1.1" 200 -
# ['جیسا کرو گے ویسا بھرو گے']
# 127.0.0.1 - - [23/Dec/2021 18:56:56] "POST /onSubmitClick HTTP/1.1" 200 -

# %%
deli='.-'
print(type(deli))
# Out:
# <class 'str'>

# %%
deli='.'+chr(1748)
print(type(deli))
# Out:
# <class 'str'>

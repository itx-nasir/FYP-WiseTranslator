# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# cp -R /content/drive/MyDrive/Final_FYP /content/sample_data

# %%
# %cd /content/sample_data/Final_FYP
# Out:
# /content/sample_data/Final_FYP

# %%
# %cd /content/
# !mkdir -p /drive/ngrok-ssh
# %cd /drive/ngrok-ssh
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip -O ngrok-stable-linux-amd64.zip
# !unzip -u ngrok-stable-linux-amd64.zip
# !cp /drive/ngrok-ssh/ngrok /ngrok
# !chmod +x /ngrok
# Out:
# /content
# /drive/ngrok-ssh
# --2021-12-18 09:04:04--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 52.202.168.65, 54.237.133.81, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  37.1MB/s    in 0.4s
#
# 2021-12-18 09:04:05 (37.1 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# !/ngrok authtoken 22Pkv75zTNFxJouVh5dV9803ZLk_7mTsPraNhuoatVfbK1MFr
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !pip install flask_ngrok

# %%
from flask import Flask,render_template,request
from TransformerModel.Translator import *
from flask_ngrok import run_with_ngrok
app = Flask(__name__)
run_with_ngrok(app) 


@app.route('/')
def homePage():

    return render_template('index.html')
@app.route('/onSubmitClick',methods=['POST'])
def onSubmitClick():
    selection=request.form.get("langSelection")
    eng=""
    urd=""
    if(selection=="1"):
        # global eng
        # global urd
        eng=request.form['EngInput']
        urd=Eng_To_Urd(eng)
    elif(selection=="2"):
        # global urd
        # global eng
        urd=request.form['UrdInput']
        eng=Urd_To_Eng(urd)

    return render_template("index.html",eng=eng,urd=urd)

if __name__ == '__main__':
    loadModels()
    app.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-beb39b6cca77> in <module>()
#       1 from flask import Flask,render_template,request
# ----> 2 from TransformerModel.Translator import *
#       3 from flask_ngrok import run_with_ngrok
#       4 app = Flask(__name__)
#       5 run_with_ngrok(app)
#
# ModuleNotFoundError: No module named 'TransformerModel'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %cd /content/drive/MyDrive/Final_FYP
# Out:
# /content/drive/MyDrive/Final_FYP

# %%
# %ls
# Out:
# app.py             FYP.ipynb              static/
# Batching.py        HyperParameters.py     templates/
# BeamSearch.py      Model.py               Tokenizer.py
# DataCleaning.py    MultiHeadAttention.py  Trainer.py
# DataGeneration.py  Normalization.py       TransformerModel/
# Decoder.py         Optimizer.py           Translator.py
# Embedding.py       PositionalEncoding.py  weightsETU/
# Encoder.py         Preprocessor.py        weightsUTE/
# Evaluate.py        __pycache__/
# FeedForward.py     Reduce.py

# %%
# !python app.py
# Out:
# Traceback (most recent call last):
#   File "app.py", line 2, in <module>
#     from Translator import *
#   File "/content/drive/MyDrive/Final_FYP/Translator.py", line 7, in <module>
#     from Preprocessor import *
#   File "/content/drive/MyDrive/Final_FYP/Preprocessor.py", line 5, in <module>
#     import spacy
#   File "/usr/local/lib/python3.7/dist-packages/spacy/__init__.py", line 10, in <module>
#     from thinc.neural.util import prefer_gpu, require_gpu
#   File "/usr/local/lib/python3.7/dist-packages/thinc/neural/__init__.py", line 4, in <module>
#     from ._classes.model import Model  # noqa: F401
#   File "/usr/local/lib/python3.7/dist-packages/thinc/neural/_classes/model.py", line 7, in <module>
#     import srsly
#   File "/usr/local/lib/python3.7/dist-packages/srsly/__init__.py", line 6, in <module>
#     from ._msgpack_api import read_msgpack, write_msgpack, msgpack_dumps, msgpack_loads
# ...
